# %%
#Rakshya Baral
# Student_id : 2431168
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# 3 Tasks - To - Do:
# Please Solve all the Problems as instructed:
# 3.1 Problem - 1: Getting Started with Data Exploration - Some Warm up
# Exercises:
# 1. Data Exploration and Understanding:
# • Dataset Overview:
# 1. Load the dataset and display the first 10 rows.
# 2. Identify the number of rows and columns in the dataset.
# 3. List all the columns and their data types.

# %%
import pandas as pd
dataset = pd.read_csv("/content/drive/MyDrive/Concepts and Technologies of AI./ WHR-2024-5CS037.csv")
print("The first 10 rows of the dataset:")
print(dataset.head(10))
rows, columns = dataset.shape
print("\nTotal number of rows:", rows)
print("Total number of columns:", columns)
print("Columns along with their data types:")
print(dataset.dtypes)
# Out:
# The first 10 rows of the dataset:
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...

# %% [markdown]
# • Basic Statistics:
# 1. Calculate the mean, median, and standard deviation for the Score column.
# 2. Identify the country with the highest and lowest happiness scores.

# %%
mean_value_of_score = dataset['score'].mean()
median_value_of_score = dataset['score'].median()
std_dev_value_of_score = dataset['score'].std()

print("Basic Statistics for the 'score' column:")
print("Mean:", mean_value_of_score)
print("Median:", median_value_of_score)
print("Standard Deviation:", std_dev_value_of_score)

highest_score_row = dataset.loc[dataset['score'].idxmax()]
lowest_score_row = dataset.loc[dataset['score'].idxmin()]

print("Country that has the highest happiness score:")
print("Country:", highest_score_row['Country name'], ", score:", highest_score_row['score'])

print("Country that has the lowest happiness score:")
print("Country:", lowest_score_row['Country name'], ", score:", lowest_score_row['score'])
# Out:
# Basic Statistics for the 'score' column:
# Mean: 5.52758041958042
# Median: 5.785
# Standard Deviation: 1.1707165099442995
# Country that has the highest happiness score:
# Country: Finland , score: 7.741
# Country that has the lowest happiness score:
# Country: Afghanistan , score: 1.721

# %% [markdown]
# • Missing Values:
# 1. Check if there are any missing values in the dataset. If so, display the total count for each column.

# %%
missing_data = dataset.isnull().sum()

print("Missing Data in the Dataset:")
print(missing_data)
# Out:
# Missing Data in the Dataset:
# Country name                    0
# score                           0
# Log GDP per capita              3
# Social support                  3
# Healthy life expectancy         3
# Freedom to make life choices    3
# Generosity                      3
# Perceptions of corruption       3
# Dystopia + residual             3
# dtype: int64

# %% [markdown]
# • Filtering and Sorting:
# 1. Filter the dataset to show only the countries with a Score greater than 7.5.
# 2. For the filtered dataset - Sort the dataset by GDP per Capita in descending order and display the
# top 10 rows.

# %%
filtered_dataset = dataset[dataset['score'] > 7.5]
print(" Filtered dataset with scores greater than 7.5.")
print(filtered_dataset)
sorted_dataset = filtered_dataset.sort_values(by='Log GDP per capita', ascending=False)
print("\n First 10 rows of the filtered dataset sorted by GDP per Capita:")
print(sorted_dataset.head(10))
# Out:
#  Filtered dataset with scores greater than 7.5.
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
#
#    Perceptions of corruption  Dystopia + residual
# 0                      0.546                2.082
# 1                      0.548                1.881
# 2                      0.182                2.050
#
#  First 10 rows of the filtered dataset sorted by GDP per Capita:
#   Country name  score  Log GDP per capita  Social support  \
# 1      Denmark  7.583               1.908           1.520
# ...

# %% [markdown]
# • Adding New Columns:
# 1. Create a new column called Happiness Category that categorizes countries into three categories
# based on their Score:
#
# Low − (Score < 4)
# Medium − (4 ≤ Score ≤ 6)
# High − (Score > 6)

# %%
def categorize_happiness(score):
    if score < 4:
        return 'Low'
    elif 4 <= score <= 6:
        return 'Medium'
    else:
        return 'High'
dataset['Happiness Category'] = dataset['score'].apply(categorize_happiness)

print(dataset[['Country name', 'score', 'Happiness Category']])
# Out:
#          Country name  score Happiness Category
# 0             Finland  7.741               High
# 1             Denmark  7.583               High
# 2             Iceland  7.525               High
# 3              Sweden  7.344               High
# 4              Israel  7.341               High
# ..                ...    ...                ...
# 138  Congo (Kinshasa)  3.295                Low
# 139      Sierra Leone  3.245                Low
# 140           Lesotho  3.186                Low
# 141           Lebanon  2.707                Low
# 142       Afghanistan  1.721                Low
#
# [143 rows x 3 columns]

# %% [markdown]
# 2. Data Visualizations:
# • Bar Plot: Plot the top 10 happiest countries by Score using a bar chart.

# %%
import matplotlib.pyplot as plt
top_10_happiest = dataset[['Country name', 'score']].sort_values(by='score', ascending=False).head(10)
plt.figure(figsize=(10, 6))
plt.bar(top_10_happiest['Country name'], top_10_happiest['score'], color='skyblue')
plt.xlabel('Country Name')
plt.ylabel('Score')
plt.title('Top 10 countries ranked by Happiness Score')
plt.show()

# %% [markdown]
# • Line Plot: Plot the top 10 unhappiest countries by Score using a Line chart.

# %%
top_10_unhappiest = dataset[['Country name', 'score']].sort_values(by='score').head(10)
plt.figure(figsize=(10, 6))
plt.plot(top_10_unhappiest['Country name'], top_10_unhappiest['score'], marker='o', color='darkblue', linestyle='-', linewidth=2, markersize=6)
plt.xlabel('Country Name')
plt.ylabel('Score')
plt.title('Top 10 Unhappiest Countries by Score')
plt.show()

# %% [markdown]
# • Plot a histogram for the Score column to show its distribution and also interpret.

# %%
plt.figure(figsize=(10, 6))
plt.hist(dataset['score'], bins=15, color='skyblue', edgecolor='black' )
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.title('Histogram of Scores')
plt.grid(True)

plt.show()

# %% [markdown]
# Interpretation:
# This histogram shows the distribution of happiness scores, where the X-axis represents the score, ranging from 0 to 8, and the Y-axis represents the frequency, ranging from 0 to 25. Most of the happiness scores lie between 6 and 7. Only a few countries have lower happiness scores, as there are fewer scores below 4. The distribution appears to be left-skewed, with most countries having higher happiness scores.

# %% [markdown]
# • Scatter Plot: Plot a scatter plot between GDP per Capita and Score to visualize their relationship.

# %%
plt.figure(figsize=(10, 6))
plt.scatter(dataset['Log GDP per capita'], dataset['score'], color='blue', alpha=0.6)
plt.xlabel('GDP per Capita')
plt.ylabel('Score')
plt.title('Scatter Plot between GDP per Capita and Happiness Score')
plt.grid(True)
plt.show()

# %% [markdown]
# This Scatter plot shows the realtionship between GDP per capita on X-axis and the Hapiness Score on Y-axis. It shows the positive correlation as GDP per capita increases happiness score also tends to increase.This means countries which has higher economic prosperity generally tend to be happier. However countries with similar GDP levels may still have different happiness score due to other factors.

# %% [markdown]
# 3.2 Problem - 2 - Some Advance Data Exploration Task:
# Task - 1 - Setup Task - Preparing the South-Asia Dataset:
# Steps:
# 1. Define the countries in South Asia with a list for example:
# south asian countries = ["Afghanistan", "Bangladesh", "Bhutan", "India",
#
# "Maldives", "Nepal", "Pakistan", "Srilanka"]

# %%
south_asian_countries = [
    "Afghanistan", "Bangladesh", "Bhutan", "India",
    "Maldives", "Nepal", "Pakistan", "Sri Lanka"
]
print("South Asian Countries: " ,south_asian_countries)
# Out:
# South Asian Countries:  ['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Maldives', 'Nepal', 'Pakistan', 'Sri Lanka']

# %% [markdown]
# 2. Use the list from step - 1 to filtered the dataset {i.e. filtered out matching dataset from list.}

# %%
south_asian_countries_dataset = dataset[dataset['Country name'].isin(south_asian_countries)]
print(south_asian_countries_dataset)
# Out:
#     Country name  score  Log GDP per capita  Social support  \
# 92         Nepal  5.158               0.965           0.990
# 107     Pakistan  4.657               1.069           0.600
# 125        India  4.054               1.166           0.653
# 127    Sri Lanka  3.898               1.361           1.179
# 128   Bangladesh  3.886               1.122           0.249
# 142  Afghanistan  1.721               0.628           0.000
#
#      Healthy life expectancy  Freedom to make life choices  Generosity  \
# 92                     0.443                         0.653       0.209
# 107                    0.321                         0.542       0.144
# 125                    0.417                         0.767       0.174
# 127                    0.586                         0.583       0.144
# 128                    0.513                         0.775       0.140
# 142                    0.242                         0.000       0.091
#
# ...

# %% [markdown]
# 3. Save the filtered dataframe as separate CSV files for future use.

# %%
south_asian_countries_dataset.to_csv("/content/drive/MyDrive/Concepts and Technologies of AI./south_asia_dataset.csv", index=False)
print("The filtered dataset has been stored as 'south_asia_dataset.csv'.")
# Out:
# The filtered dataset has been stored as 'south_asia_dataset.csv'.

# %% [markdown]
# Task - 2 - Composite Score Ranking:
# Tasks:
# 1. Using the SouthAsia DataFrame, create a new column called Composite Score that combines the
# following metrics:
#
# Composite Score = 0.40 × GDP per Capita + 0.30 × Social Support
#
# + 0.30 × Healthy Life Expectancy
# 2. Rank the South Asian countries based on the Composite Score in descending order.
# 3. Visualize the top 5 countries using a horizontal bar chart showing the Composite Score.
# 4. Discuss whether the rankings based on the Composite Score align with the original Score - support your
# discussion with some visualization plot.

# %%
south_asian_countries_dataset.loc[:, 'Composite Score'] = (
    0.40 * south_asian_countries_dataset['Log GDP per capita'] +
    0.30 * south_asian_countries_dataset['Social support'] +
    0.30 * south_asian_countries_dataset['Healthy life expectancy']
)

south_asia_dataset_sorted = south_asian_countries_dataset.sort_values(by='Composite Score', ascending=False)
top_5_composite = south_asia_dataset_sorted.head(5)

plt.figure(figsize=(6, 6))
plt.bar(top_5_composite['Country name'], top_5_composite['Composite Score'], color='grey')
plt.xlabel('Country Name')
plt.ylabel('Composite Score')
plt.title('Top 5 South Asian Countries by Composite Score')
plt.show()

comparing_scores_df=south_asian_countries_dataset[['Country name', 'Composite Score','score']]
plt.figure(figsize=(10, 6))
plt.barh(comparing_scores_df['Country name'], comparing_scores_df['Composite Score'],color='brown', label='Composite Score')
plt.barh(comparing_scores_df['Country name'], comparing_scores_df['score'],color='pink',alpha=0.7, label='Original Score')

plt.title('Comparing Composite Score and Original Score ')
plt.xlabel('Scores')
plt.ylabel('Country Name')
plt.legend(title='Score Type')
plt.show()
# Out:
# <ipython-input-65-bc656ad9cd78>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_asian_countries_dataset.loc[:, 'Composite Score'] = (

# %% [markdown]
# Task - 3 - Outlier Detection:
# Tasks:
# 1. Identify outlier countries in South Asia based on their Score and GDP per Capita.
# 2. Define outliers using the 1.5 × IQR rule.
# 3. Create a scatter plot with GDP per Capita on the x-axis and Score on the y-axis, highlighting outliers
# in a different color.
# 4. Discuss the characteristics of these outliers and their potential impact on regional averages.

# %%
import matplotlib.pyplot as plt
def detect_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] < lower_bound) | (df[column] > upper_bound)]
score_outliers = detect_outliers(south_asian_countries_dataset, 'score')
gdp_outliers = detect_outliers(south_asian_countries_dataset, 'Log GDP per capita')

outliers = pd.concat([score_outliers, gdp_outliers]).drop_duplicates()

plt.figure(figsize=(10, 6))

plt.scatter(south_asian_countries_dataset['Log GDP per capita'], south_asian_countries_dataset['score'], color='blue', alpha=0.6, label='Normal')

plt.scatter(outliers['Log GDP per capita'], outliers['score'], color='red', label='Outliers')

plt.xlabel('GDP per Capita')
plt.ylabel('Score')
plt.title('Scatter Plot of GDP per Capita vs. Happiness Score with Outliers')
plt.legend()
plt.grid(True)
plt.show()

print("Outlier countries based on Score and GDP per Capita:")
print(outliers[['Country name', 'Log GDP per capita', 'score']])
# Out:
# Outlier countries based on Score and GDP per Capita:
#     Country name  Log GDP per capita  score
# 142  Afghanistan               0.628  1.721

# %% [markdown]
# These outlier are the extreme values that are present in the columns .These outliers have some effects on the mean but a less effect on the  median and the mode.

# %% [markdown]
# Task - 4 - Exploring Trends Across Metrics:
# Tasks:
# 1. Choose two metrics (e.g., Freedom to Make Life Choices and Generosity) and calculate their correlation
# {pearson correlation} with the Score for South Asian countries.
# 2. Create scatter plots with trendlines for these metrics against the Score.
# 3. Identify and discuss the strongest and weakest relationships between these metrics and the Score for
# South Asian countries.

# %%
import seaborn as sb
freedom = south_asian_countries_dataset['Freedom to make life choices']
generosity = south_asian_countries_dataset['Generosity']
scr = south_asian_countries_dataset['score']

cor_freedom = freedom.corr(scr, method='pearson')
cor_generosity = generosity.corr(scr, method='pearson')

print("Correlation between Freedom to Make Life Choices and Score:", cor_freedom)
print("Correlation between Generosity and Score:", cor_generosity)

plt.figure(figsize=(12, 6))
sb.regplot(x='Freedom to make life choices', y='score', data=south_asian_countries_dataset,
           ci=None, scatter_kws={'color':'blue'}, line_kws={'color':'green'})
plt.title('Freedom vs Score')
plt.xlabel('Freedom to Make Life Choices')
plt.ylabel('Score')
plt.show()

plt.figure(figsize=(12, 6))
sb.regplot(x='Generosity', y='score', data=south_asian_countries_dataset,
           ci=None, scatter_kws={'color':'red'}, line_kws={'color':'skyblue'})
plt.title('Generosity vs Score')
plt.xlabel('Generosity')
plt.ylabel('Score')
plt.tight_layout()
plt.show()
# Out:
# Correlation between Freedom to Make Life Choices and Score: 0.8005185224163315
# Correlation between Generosity and Score: 0.874512371253192

# %% [markdown]
# The above plots and the correlation analysis show a positive correlation between Generosity and Freedom to make life choices with the score. From the above plots it indicates that freedom to make life choices has a impactful relationship with scores in South Asia rather than generosity.

# %% [markdown]
# Task - 5 - Gap Analysis:
# Tasks:
# 1. Add a new column, GDP-Score Gap, which is the difference between GDP per Capita and the Score
# for each South Asian country.
# 2. Rank the South Asian countries by this gap in both ascending and descending order.
# 3. Highlight the top 3 countries with the largest positive and negative gaps using a bar chart.
# 4. Analyze the reasons behind these gaps and their implications for South Asian countries.

# %%
south_asian_countries_dataset['GDP-Score Gap'] = south_asian_countries_dataset['Log GDP per capita'] - south_asian_countries_dataset['score']
print(south_asian_countries_dataset[['Country name', 'Log GDP per capita', 'score', 'GDP-Score Gap']])

gap_rank_descending = south_asian_countries_dataset.sort_values(by='GDP-Score Gap', ascending=False)
print("Countries ranked by GDP-Score Gap (Descending):")
print(gap_rank_descending[['Country name', 'GDP-Score Gap']])
gap_rank_ascending = south_asian_countries_dataset.sort_values(by='GDP-Score Gap', ascending=True)
print("Countries ranked by GDP-Score Gap (Ascending):")
print(gap_rank_ascending[['Country name', 'GDP-Score Gap']])

top_3_positive_gap = gap_rank_descending.head(3)
top_3_negative_gap = gap_rank_ascending.head(3)

plt.figure(figsize=(10, 6))

sb.barplot(x='GDP-Score Gap', y='Country name', data=top_3_positive_gap, color='skyblue', label='Positive Gap')
sb.barplot(x='GDP-Score Gap', y='Country name', data=top_3_negative_gap, color='lavender',label='Negative Gap')

plt.title('Top 3 Countries with Largest Positive and Negative GDP-Score Gaps')
plt.xlabel('GDP-Score Gap')
plt.ylabel('Country Name')
plt.legend()
plt.show()
# Out:
# <ipython-input-68-6e413ac20d7d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   south_asian_countries_dataset['GDP-Score Gap'] = south_asian_countries_dataset['Log GDP per capita'] - south_asian_countries_dataset['score']
#     Country name  Log GDP per capita  score  GDP-Score Gap
# 92         Nepal               0.965  5.158         -4.193
# 107     Pakistan               1.069  4.657         -3.588
# 125        India               1.166  4.054         -2.888
# 127    Sri Lanka               1.361  3.898         -2.537
# 128   Bangladesh               1.122  3.886         -2.764
# 142  Afghanistan               0.628  1.721         -1.093
# Countries ranked by GDP-Score Gap (Descending):
#     Country name  GDP-Score Gap
# ...

# %% [markdown]
# 3.3 Problem - 3 - Comparative Analysis:
# Task - 1 - Setup Task - Preparing the Middle Eastern Dataset:
# Tasks:
# 1. Similar in Task - 1 of Problem 2 create a dataframe from middle eastern countries. For hint use the
# following list:
# middle east countries = [ "Bahrain", "Iran", "Iraq", "Israel", "Jordan",
# "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar", "Saudi Arabia", "Syria",
#
# "United Arab Emirates", "Yemen"]

# %%
middle_east_countries = ["Bahrain", "Iran", "Iraq", "Israel", "Jordan",
                         "Kuwait", "Lebanon", "Oman", "Palestine", "Qatar",
                         "Saudi Arabia", "Syria", "United Arab Emirates", "Yemen"]
middle_east_dataset = dataset[dataset['Country name'].isin(middle_east_countries)]
middle_east_dataset.head()
# Out:
#             Country name  score  Log GDP per capita  Social support  \
# 4                 Israel  7.341               1.803           1.513
# 12                Kuwait  6.951               1.845           1.364
# 21  United Arab Emirates  6.733               1.983           1.164
# 27          Saudi Arabia  6.594               1.842           1.361
# 61               Bahrain  5.959                 NaN             NaN
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                     0.740                         0.641       0.153
# 12                    0.661                         0.827       0.200
# 21                    0.563                         0.815       0.209
# 27                    0.511                         0.787       0.114
# 61                      NaN                           NaN         NaN
#
#     Perceptions of corruption  Dystopia + residual Happiness Category
# ...

# %% [markdown]
# Complete the following task:
# 1. Descriptive Statistics:
# • Calculate the mean, Standard deviation of the score for both South Asia and Middle East.
# • Which region has higher happiness Scores on average?

# %%
South_Asia_Mean = south_asian_countries_dataset["score"].mean()
Mid_Eastern_Mean =middle_east_dataset["score"].mean()

sAsia_std =south_asian_countries_dataset["score"].std()
midEast_std = middle_east_dataset["score"].std()

print(f"\nSouth Asia \n Mean: {South_Asia_Mean} \n Standard Deviation: {sAsia_std}")
print(f"\nMiddle East \n Mean: {Mid_Eastern_Mean} \n Standard Deviation: {midEast_std}")
# Out:
# South Asia
#  Mean: 3.895666666666667
#  Standard Deviation: 1.1770690152521504
#
# Middle East
#  Mean: 5.412100000000001
#  Standard Deviation: 1.5662011684327144

# %% [markdown]
# The Middle East has higher happiness scores on average compared to South Asia.

# %% [markdown]
# 2. Top and Bottom Performers:
# • Identify the top 3 and bottom 3 countries in each region based on the score.
# • Plot bar charts comparing these charts.

# %%
South_Asia_top=south_asian_countries_dataset.nlargest(3,"score")
Mid_East_top=middle_east_dataset.nlargest(3,"score")

South_Asia_bottom=south_asian_countries_dataset.nsmallest(3,"score")
Mid_East_bottom=middle_east_dataset.nsmallest(3,"score")

plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
sb.barplot(x="score",y="Country name",data=pd.concat([South_Asia_top,South_Asia_bottom]))
plt.title("Top and bottom 3 countries - South Asia")

plt.subplot(1,2,2)
sb.barplot(x="score",y="Country name",data=pd.concat([Mid_East_top,Mid_East_bottom]))
plt.title("Top and bottom 3 countries - Middle East")

plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Metric Comparisons:
# • Compare key metrics like GDP per Capita, Social Support, and Healthy Life Expectancy
# between the regions using grouped bar charts.
# • Which metrics show the largest disparity between the two regions?

# %%
metrics=["Log GDP per capita", "Social support", "Healthy life expectancy"]

South_Asia_Metrics=south_asian_countries_dataset[metrics].mean()
Middle_East_Metrics=middle_east_dataset[metrics].mean()
comp_df=pd.DataFrame({"South Asia":South_Asia_Metrics,"Middle East":Middle_East_Metrics})

comp_df.plot(kind="bar", figsize=(6,6), color=["cyan","pink"])
plt.title("Comparison of key Metrics beteen south asia and middle east")
plt.ylabel("Average values")
plt.xlabel("Key Metrics")
plt.show()

# %% [markdown]
# 4. Happiness Disparity:
# • Compute the range (max - min) and coefficient of variation (CV) for Score in both regions.
# • Which region has greater variability in happiness?

# %%
def compt(df,clmn):
  range=df[clmn].max()-df[clmn].min()
  cv=df[clmn].std()/df[clmn].mean()
  return range, cv

South_Asian_Range, sAsian_cv = compt(south_asian_countries_dataset, 'score')
Mid_East_Range, midEast_cv = compt(middle_east_dataset, 'score')

print(f"\nSouth Asia \n Range: {South_Asian_Range} \n CV: {sAsian_cv}")
print(f"\nMiddle East \n Range: {Mid_East_Range} \n CV: {midEast_cv}")
# Out:
# South Asia
#  Range: 3.4370000000000003
#  CV: 0.3021482883337427
#
# Middle East
#  Range: 4.634
#  CV: 0.28938880812119405

# %% [markdown]
# South Asia has greater variability in happiness.

# %% [markdown]
# 5. Correlation Analysis:
# • Analyze the correlation of Score with other metrics Freedom to Make Life Choices, and
# Generosity within each region.
# • Create scatter plots to visualize and interpret the relationships.

# %%
metrics=["Freedom to make life choices","Generosity"]

for m in metrics:
  print(f"Correlation of Score with {m}")
  print("South Asia:", south_asian_countries_dataset['score'].corr(south_asian_countries_dataset[m]))
  print("Middle East:", middle_east_dataset['score'].corr(middle_east_dataset[m]))

for m in metrics:
  plt.figure(figsize=(10,6))
  plt.subplot(1,2,1)
  sb.scatterplot(x=m, y="score",data=south_asian_countries_dataset)
  plt.title(f"South Asia Correlation (Score with {m})")
  plt.tight_layout()
  plt.show()

  plt.figure(figsize=(10,6))
  plt.subplot(1,2,1)
  sb.scatterplot(x=m, y="score",data=middle_east_dataset)
  plt.title(f"Middle East Correlation (Score with {m})")
  plt.tight_layout()
  plt.show()
# Out:
# Correlation of Score with Freedom to make life choices
# South Asia: 0.8005185224163315
# Middle East: 0.8632202433827544
# Correlation of Score with Generosity
# South Asia: 0.874512371253192
# Middle East: 0.6275236536964182

# %% [markdown]
# 6. Outlier Detection:
# • Identify outlier countries in both regions based on Score and GDP per Capita.
# • Plot these outliers and discuss their implications.

# %%
def outlier(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = df[(df[column] < lower) | (df[column] > upper)]
    return outliers

sAsian_out_score = outlier(south_asian_countries_dataset, "score")
midEast_out_score = outlier(middle_east_dataset, "score")

plt.figure(figsize=(10, 8))

plt.subplot(2, 1, 1)
sb.boxplot(x="score", data=south_asian_countries_dataset, orient="h", showfliers=True)
plt.title("South Asia Score Distribution with Outliers")
plt.xlabel("Score")

plt.subplot(2, 1, 2)
sb.boxplot(x="score", data=middle_east_dataset, orient="h", showfliers=True)
plt.title("Middle East Score Distribution with Outliers")
plt.xlabel("Score")

plt.tight_layout()
plt.show()

# %% [markdown]
# 7. Visualization:
# • Create boxplots comparing the distribution of Score between South Asia and the Middle East.
# • Interpret the key differences in distribution shapes, medians, and outliers.

# %%
plt.figure(figsize=(8, 6))
sb.boxplot(x='Region', y='score',data=pd.concat([south_asian_countries_dataset.assign(Region="South Asia"),middle_east_dataset.assign(Region="Middle East")]))
plt.title(" Distribution of Score between South Asia and the Middle East")
plt.show()
